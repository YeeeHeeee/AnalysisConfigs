# %%
import coffea.util as cu
import pandas as pd
import numpy as np
import sys
sys.path.append('/vols/cms/yhe4823/TopSBI/Functions')
from OpenFiles import extract_dataframes
from Plotting import inital_distributions_plot, stacked_hist, heat_map, eff_plot

# %%
data = cu.load("/vols/cms/yhe4823/TopSBI/A_Run2/Merged/output_test/output_all.coffea")

# %%
df, df_dict = extract_dataframes(data)
# Out:
# Variables are:  dict_keys(['sum_genweights', 'sum_signOf_genweights', 'sumw', 'sumw2', 'cutflow', 'variables', 'columns', 'processing_metadata', 'datasets_metadata'])
# Channels are: dict_keys(['WJetsToLNu', 'TTToHadronic', 'TTTo2L2Nu', 'TTToSemiLeptonic'])
# Processing datasets: WJetsToLNu
#   WJetsToLNu_2018
#     baseline
#   WJetsToLNu_2017
#     baseline
#   WJetsToLNu_2016_PostVFP
#     baseline
#   WJetsToLNu_2016_PreVFP
#     baseline
# Processing datasets: TTToHadronic
#   TTToHadronic_2018
#     baseline
# Processing datasets: TTTo2L2Nu
#   TTTo2L2Nu_2018
#     baseline
#   TTTo2L2Nu_2017
#     baseline
#   TTTo2L2Nu_2016_PostVFP
#     baseline
#   TTTo2L2Nu_2016_PreVFP
#     baseline
# Processing datasets: TTToSemiLeptonic
#   TTToSemiLeptonic_2018
#     baseline
#   TTToSemiLeptonic_2017
#     baseline
#   TTToSemiLeptonic_2016_PostVFP
#     baseline
#   TTToSemiLeptonic_2016_PreVFP
#     baseline
